# %% [markdown]
# <a href="https://colab.research.google.com/github/gayathripati31/FMML_LABS/blob/main/Module_8_Lab__3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-28 14:55:37--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   205MB/s    in 0.3s
#
# 2024-03-28 14:55:37 (205 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                   id                                            summary   tag  \
# 6977    1708.05594v1  The analysis of mixed data has been raising ch...    cs
# 34166   1503.02801v1  Due to computational and storage efficiencies ...    cs
# 32740  1504.06952v21  To address the contextual bandit problem, we p...    cs
# 34878    1203.6276v4  Variable selection is recognized as one of the...  stat
# 35614    1006.1407v1  Interval temporal logics (ITLs) are logics for...    cs
# ...              ...                                                ...   ...
# 21798   1604.01602v2  Research on manifold learning within a density...  stat
# 14064   1707.06185v1  Many assembly lines related optimization probl...    cs
# 7679    1802.07756v1  Motivation: Thanks to digitization, we often h...  stat
# 7254    1711.04992v2  Understanding the influence of features in mac...  stat
# 11369   1511.04156v2  Neuroprosthetic brain-computer interfaces func...  stat
#
#                                                    title  year  \
# 6977   Statistical Latent Space Approach for Mixed Da...  2017
# 34166  Short Text Hashing Improved by Integrating Mul...  2015
# 32740  Random Forest for the Contextual Bandit Proble...  2015
# 34878  A Multi-objective Exploratory Procedure for Re...  2012
# 35614  Begin, After, and Later: a Maximal Decidable I...  2010
# ...                                                  ...   ...
# 21798           Manifold unwrapping using density ridges  2016
# 14064  Simultaneously Solving Mixed Model Assembly Li...  2017
# 7679   Determining the best classifier for predicting...  2018
# 7254   Feature importance scores and lossless feature...  2017
# 11369  Neuroprosthetic decoder training as imitation ...  2015
#
#                                                 keywords
# 6977   [challenges, statistics, prominent, challenges...
# 34166  [computational, efficiencies, similarity, unfo...
# 32740  [contextual, algorithm, algorithm, complexity,...
# 34878  [selection, recognized, statistical, encounter...
# 35614  [reasoning, statements, expressed, intervals, ...
# ...                                                  ...
# 21798  [estimation, framework, potential, estimation,...
# 14064  [optimization, researchers, relevance, manufac...
# 7679   [motivation, digitization, databases, consisti...
# 7254   [understanding, influence, interpreting, selec...
# 11369  [neuroprosthetic, interfaces, algorithm, movem...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 6977     [challenges, statistics, prominent, challenges...
# 34166    [computational, efficiencies, similarity, unfo...
# 32740    [contextual, algorithm, algorithm, complexity,...
# 34878    [selection, recognized, statistical, encounter...
# 35614    [reasoning, statements, expressed, intervals, ...
#                                ...
# 10739    [processes, parametric, probabilistic, regress...
# 17016    [discusses, uwaterloo, sentiment, describes, v...
# 27647    [segmentation, algorithms, potential, differen...
# 22561    [construction, synthetic, observations, import...
# 22293    [stochastic, variational, inference, collapsed...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8860 words.
# Out of those 4564 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fd7fdd54-3ad9-4f3b-8e8b-85735155a591" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fd7fdd54-3ad9-4f3b-8e8b-85735155a591")) {                    Plotly.newPlot(                        "fd7fdd54-3ad9-4f3b-8e8b-85735155a591",                        [{"x":["challenge","prominent","transform","integrate","statistics","including","parameter","applications","boltzmann","techniques","methodologies","demonstrate","statistical","retrieval","restricted","representation","homogeneous","effectively","challenges","heterogeneous","introduce","experimental","extensions","balancing","structured","outperform","modelling","information","outperforms","similarity","particular","integrating","strategies","incorporate","computational","represent","researchers","intrinsic","baselines","significantly","selection","experiments","granularity","unfortunately","sparseness","depending","effective","efficiencies","extensive","evaluation","algorithms","logarithmic","assembled","complexity","dependencies","dependence","potentially","variables","illustrate","contextual","algorithm","theoretical","efficient","analytical","promising","comparison","collection","exploratory","difficulty","importance","communities","generalization","exploration","intervention","published","abundance","procedure","minimization","evaluated","interdependencies","considers","characterized","encountered","regression","engineering","coefficients","dominated","linearities","performed","eliminating","recognized","knowledge","regressors","explanatory","preferred","objective","introduces","contribution","satisfiability","relations","undecidable","classification","combinations","fragments","decidable","combination","expressed","discovered","different","intervals","decidability","considered","reasoning","statements","exceptions","mentioned","detecting","clustering","qualitative","difficult","accelerated","available","performance","supporting","comparable","hierarchical","significant","improvement","instances","simultaneously","generalize","convolutions","sophisticated","intelligent","controller","addressing","partially","observable","obstacles","satisfactorily","necessary","convolutional","environment","architecture","augmented","environments","factorization","framework","additional","maintaining","inference","optimality","conditions","probabilistic","rectification","stochastic","heuristics","interactions","scalability","differences","considerable","introducing","attracted","processing","originally","coarsening","producing","parallelizing","applicable","developed","technique","constraints","partition","addresses","propagation","resulting","competing","evolutionary","partitioning","refinement","multilevel","classifier","predicting","ensembles","classifiers","ubiquitous","attributes","dimension","additionally","selecting","relational","components","discovering","snapshots","component","representations","capability","influence","traditional","necessity"],"y":[158,21,70,43,62,219,121,410,16,406,21,575,149,100,42,363,15,117,136,30,338,371,52,13,105,71,57,685,239,159,317,39,100,57,275,115,69,36,56,253,166,556,12,55,4,35,258,4,153,250,565,11,6,246,54,30,42,109,89,35,835,171,391,18,123,130,79,12,45,99,10,105,58,9,44,5,119,64,149,2,30,32,18,119,38,28,8,2,123,11,24,355,3,2,12,165,73,79,15,85,7,496,39,12,7,137,35,27,752,14,7,125,123,13,5,16,69,130,55,151,10,306,857,21,83,94,215,155,89,101,52,19,32,69,22,31,50,21,14,3,67,388,114,227,47,82,45,498,108,43,230,19,118,160,4,128,52,66,29,55,32,53,26,316,15,2,38,2,44,216,246,157,41,59,63,171,21,63,18,31,6,129,91,18,96,18,75,60,55,44,28,93,37,1,94,225,53,54,172,12],"type":"bar"},{"x":["challenge","prominent","transform","integrate","statistics","includ ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4564,), (4564, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8183333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.5625);'>Conceptual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Modelling</span> <span style=''>and</span> <span style=''>The</span> <span style=''>Quality</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>Ontologies</span> <span style=''>Endurantism</span> <span style=''>Vs</span> <span style=''>Perdurantism</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>Ontologies</span> <span style=''>are</span> <span style=''>key</span> <span style=''>enablers</span> <span style=''>for</span> <span style=''>sharing</span> <span style=''>precise</span> <span style=''>and</span> <span style=''>machine</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understandable</span> <span style='background-color:rgba(0, 255, 0, 0.8979591836734695);'>semantics</span> <span style=''>among</span> <span style='background-color:rgba(0, 255, 0, 0.31239092495637);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>and</span> <span style=''>parties</span> <span style=''>Yet</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>ontologies</span> <span style=''>to</span> <span style=''>meet</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expectations</span> <span style=''>their</span> <span style=''>quality</span> <span style=''>must</span> <span style=''>be</span> <span style=''>of</span> <span style=''>a</span> <span style=''>good</span> <span style=''>standard</span> <span style=''>The</span> <span style=''>quality</span> <span style=''>of</span> <span style=''>an</span> <span style=''>ontology</span> <span style=''>is</span> <span style=''>strongly</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>design</span> <span style=''>method</span> <span style=''>employed</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.3258426966292135);'>addresses</span> <span style=''>the</span> <span style=''>design</span> <span style=''>problems</span> <span style=''>related</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modelling</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777777);'>ontologies</span> <span style=''>with</span> <span style=''>specific</span> <span style='background-color:rgba(255, 0, 0, 0.3658536585365854);'>concentration</span> <span style=''>on</span> <span style=''>the</span> <span style=''>issues</span> <span style=''>related</span> <span style=''>to</span> <span style=''>the</span> <span style=''>quality</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>conceptualisations</span> <span style=''>produced</span> <span style=''>The</span> <span style=''>paper</span> <span style=''>aims</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style=''>impact</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modelling</span> <span style=''>paradigm</span> <span style=''>adopted</span> <span style=''>on</span> <span style=''>the</span> <span style=''>quality</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>ontological</span> <span style=''>models</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consequently</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>potential</span> <span style=''>impact</span> <span style=''>that</span> <span style=''>such</span> <span style=''>a</span> <span style=''>decision</span> <span style=''>can</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Overpruning</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style=''>Bayesian</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>motivations</span> <span style=''>for</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>(VI)</span> <span style=''>in</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>differ</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>from</span> <span style=''>those</span> <span style=''>in</span> <span style=''>latent</span> <span style=''>variable</span> <span style=''>models</span> <span style=''>This</span> <span style=''>has</span> <span style=''>a</span> <span style=''>counter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intuitive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consequence</span> <span style=''>more</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>can</span> <span style=''>provide</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>worse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>as</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>those</span> <span style=''>with</span> <span style=''>less</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expressive</span> <span style=''>families</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>make</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contributions</span> <span style=''>First</span> <span style=''>we</span> <span style=''>identify</span> <span style=''>a</span> <span style=''>cause</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>gap</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>over</span> <span style=''>pruning</span> <span style=''>Second</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretically</span> <span style=''>grounded</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explanation</span> <span style=''>for</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>phenomenon</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perspective</span> <span style=''>sheds</span> <span style=''>light</span> <span style=''>on</span> <span style=''>several</span> <span style=''>related</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>published</span> <span style=''>results</span> <span style=''>and</span> <span style=''>provides</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intuition</span> <span style=''>into</span> <span style=''>the</span> <span style=''>design</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>of</span> <span style=''>neural</span> <span style=''>networks</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Submodularity</span> <span style=''>in</span> <span style=''>Batch</span> <span style=''>Active</span> <span style=''>Learning</span> <span style=''>and</span> <span style=''>Survey</span> <span style=''>Problems</span> <span style=''>on</span> <span style=''>Gaussian</span> <span style=''>Random</span> <span style=''>Fields</span> <br/><br/><span style=''>Many</span> <span style=''>real</span> <span style=''>world</span> <span style=''>datasets</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>represented</span> <span style=''>in</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style=''>a</span> <span style=''>graph</span> <span style=''>whose</span> <span style=''>edge</span> <span style=''>weights</span> <span style=''>designate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>similarities</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.40157480314960636);'>instances</span> <span style=''>A</span> <span style=''>discrete</span> <span style=''>Gaussian</span> <span style=''>random</span> <span style=''>field</span> <span style=''>(GRF)</span> <span style=''>model</span> <span style=''>is</span> <span style=''>a</span> <span style=''>finite</span> <span style='background-color:rgba(255, 0, 0, 0.3613445378151261);'>dimensional</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>(GP)</span> <span style=''>whose</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.6146788990825688);'>covariance</span> <span style=''>is</span> <span style=''>the</span> <span style=''>inverse</span> <span style=''>of</span> <span style=''>a</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Laplacian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Minimizing</span> <span style=''>the</span> <span style=''>trace</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3689320388349515);'>predictive</span> <span style='background-color:rgba(255, 0, 0, 0.6146788990825688);'>covariance</span> <span style=''>Sigma</span> <span style=''>(V</span> <span style=''>optimality)</span> <span style=''>on</span> <span style=''>GRFs</span> <span style=''>has</span> <span style=''>proven</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>successful</span> <span style=''>in</span> <span style=''>batch</span> <span style=''>active</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>problems</span> <span style=''>with</span> <span style=''>budget</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>However</span> <span style=''>its</span> <span style=''>worst</span> <span style=''>case</span> <span style=''>bound</span> <span style=''>has</span> <span style=''>been</span> <span style=''>missing</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>V</span> <span style='background-color:rgba(255, 0, 0, 0.34482758620689646);'>optimality</span> <span style=''>on</span> <span style=''>GRFs</span> <span style=''>as</span> <span style=''>a</span> <span style=''>function</span> <span style=''>of</span> <span style=''>the</span> <span style=''>batch</span> <span style=''>query</span> <span style=''>set</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>submodular</span> <span style=''>and</span> <span style=''>hence</span> <span style=''>its</span> <span style=''>greedy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(255, 0, 0, 0.3652694610778 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regularization</span> <span style=''>Effects</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Anisotropic</span> <span style=''>Noise</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style=''>Gradient</span> <span style=''>Descent</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Understanding</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>has</span> <span style=''>raised</span> <span style=''>lots</span> <span style=''>of</span> <span style=''>concerns</span> <span style=''>recently</span> <span style=''>where</span> <span style=''>the</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>play</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>role</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>(SGD)</span> <span style=''>Along</span> <span style=''>this</span> <span style=''>line</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particularly</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>anisotropic</span> <span style=''>noise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>by</span> <span style=''>SGD</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importance</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>in</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>Through</span> <span style=''>a</span> <span style=''>thorough</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>analysis</span> <span style=''>it</span> <span style=''>is</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>anisotropic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diffusion</span> <span style=''>of</span> <span style=''>SGD</span> <span style=''>tends</span> <span style=''>to</span> <span style=''>follow</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>curvature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>of</span> <span style=''>the</span> <span style=''>loss</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>landscape</span> <span style=''>and</span> <span style=''>thus</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>beneficial</span> <span style=''>for</span> <span style=''>escaping</span> <span style=''>from</span> <span style=''>sharp</span> <span style=''>and</span> <span style=''>poor</span> <span style=''>minima</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectively</span> <span style=''>towards</span> <span style=''>more</span> <span style=''>stable</span> <span style=''>and</span> <span style=''>flat</span> <span style=''>minima</span> <span style=''>We</span> <span style=''>verify</span> <span style=''>our</span>  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.1282514450867052)
# 	experimental (0.13403179190751446)
# 	segmentation (0.07044797687861272)
# 	representation (0.1311416184971098)
# 	processing (0.11416184971098266)
# 	information (0.24747109826589594)
# 	detection (0.11849710982658959)
# 	different (0.27167630057803466)
# 	recognition (0.13258670520231214)
# 	convolutional (0.14017341040462428)
#
# Some Statistics words are:
# 	numerical (0.10974409448818898)
# 	variables (0.13041338582677164)
# 	stochastic (0.13828740157480315)
# 	estimation (0.1643700787401575)
# 	algorithm (0.3956692913385827)
# 	statistical (0.15255905511811024)
# 	distribution (0.18651574803149606)
# 	inference (0.20226377952755906)
# 	dimensional (0.19931102362204725)
# 	regression (0.17372047244094488)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c1eb2dcd-3007-47d2-a927-35f88d1c0938" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c1eb2dcd-3007-47d2-a927-35f88d1c0938")) {                    Plotly.newPlot(                        "c1eb2dcd-3007-47d2-a927-35f88d1c0938",                        [{"x":["challenge","prominent","transform","integrate","statistics","including","parameter","applications","boltzmann","techniques","methodologies","demonstrate","statistical","retrieval","restricted","representation","homogeneous","effectively","challenges","heterogeneous","introduce","experimental","extensions","balancing","structured","outperform","modelling","information","outperforms","similarity","particular","integrating","strategies","incorporate","computational","represent","researchers","intrinsic","baselines","significantly","selection","experiments","granularity","unfortunately","sparseness","depending","effective","efficiencies","extensive","evaluation","algorithms","logarithmic","assembled","complexity","dependencies","dependence","potentially","variables","illustrate","contextual","algorithm","theoretical","efficient","analytical","promising","comparison","collection","exploratory","difficulty","importance","communities","generalization","exploration","intervention","published","abundance","procedure","minimization","evaluated","interdependencies","considers","characterized","encountered","regression","engineering","coefficients","dominated","linearities","performed","eliminating","recognized","knowledge","regressors","explanatory","preferred","objective","introduces","contribution","satisfiability","relations","undecidable","classification","combinations","fragments","decidable","combination","expressed","discovered","different","intervals","decidability","considered","reasoning","statements","exceptions","mentioned","detecting","clustering","qualitative","difficult","accelerated","available","performance","supporting","comparable","hierarchical","significant","improvement","instances","simultaneously","generalize","convolutions","sophisticated","intelligent","controller","addressing","partially","observable","obstacles","satisfactorily","necessary","convolutional","environment","architecture","augmented","environments","factorization","framework","additional","maintaining","inference","optimality","conditions","probabilistic","rectification","stochastic","heuristics","interactions","scalability","differences","considerable","introducing","attracted","processing","originally","coarsening","producing","parallelizing","applicable","developed","technique","constraints","partition","addresses","propagation","resulting","competing","evolutionary","partitioning","refinement","multilevel","classifier","predicting","ensembles","classifiers","ubiquitous","attributes","dimension","additionally","selecting","relational","components","discovering","snapshots","component","representations","capability","influence","traditional","necessity","technical","magnitude","reduction","community","utilization","minibatches","properties","combining","accelerating","practitioners","accelerate","supervised","important","synthetic","preferential","landscapes","similarities","architectures","parametrized","comparing","landscape","approaching","increasingly","dynamical","numerically","suggesting","directions","distinctive","behaviors","corresponding","existence","marginals","estimating","structure","dimensional","optimization","approximation","dimensions","regularized","observations","surrogate","formulate","explicitly","demonstrated","efficiently","maximization","parameters","underlying","incorporates","estimation","estimates","convergence","likelihood","recording","substantially","tole ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	parametrically
# 	advantageously
# 	transferability
# 	disentanglement
# 	discriminants
# 	microwave
# 	revolutionize
# 	blackwellisation
# 	unanswered
# 	aerodynamic
# 	heteroscedasticity
# 	bernstein
# 	ingenious
# 	heteroskedastic
# 	subsampling
# 	thermostats
# 	governing
# 	biophysical
# 	hypernetworks
# 	affinities
# Some words which never appear in Statistics papers:
# 	assembled
# 	undecidable
# 	fragments
# 	decidable
# 	decidability
# 	satisfactorily
# 	rectification
# 	preferential
# 	memristive
# 	neuromorphic
# 	rewarding
# 	cooperating
# 	institute
# 	navigation
# 	deblurring
# 	inserting
# 	convincing
# 	unconscious
# 	communicative
# 	visibility

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.101352189554646e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7816666666666666
